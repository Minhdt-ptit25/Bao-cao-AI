# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
df = pd.read_csv(r'C:\Users\Admin\OneDrive - ptit.edu.vn\Documents\Bao cao AI\Traning_ML_Model\Data\Mall_Customers.csv')
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
for col in df.columns:
    missing_data = df[col].isna().sum()
    missing_percent = missing_data/len(df)*100
    print(f'Columns: {col} has {missing_percent:.2f} missing data')
# Out:
# Columns: CustomerID has 0.00 missing data
# Columns: Gender has 0.00 missing data
# Columns: Age has 0.00 missing data
# Columns: Annual Income (k$) has 0.00 missing data
# Columns: Spending Score (1-100) has 0.00 missing data

# %%
fig, ax = plt.subplots()
sns.heatmap(df.isna(),cmap='Blues',cbar=False,yticklabels=False);
